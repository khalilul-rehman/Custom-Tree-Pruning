# %%
import gurobipy as gp

try:
    # Attempting to create an environment triggers the license check
    with gp.Env() as env:
        with gp.Model(env=env) as model:
            print("\nSUCCESS: Gurobi license is active.")
except gp.GurobiError as e:
    print(f"\nLICENSE ERROR: {e}")
# Out:
# Set parameter Username
# Set parameter LicenseID to value 2774084
# Academic license - for non-commercial use only - expires 2027-02-02
#
# SUCCESS: Gurobi license is active.
