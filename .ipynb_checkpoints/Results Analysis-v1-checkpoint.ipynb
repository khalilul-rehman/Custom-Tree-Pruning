# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("custom_tree_experiments_results_EH_v1.csv")

df.head()
# Out:
#    system_name  max_depth cost_function  alpha  nodes_before  leaves_before  \
# 0  Exponential          4      scenario  0.001            31             16
# 1  Exponential          4      scenario  0.010            31             16
# 2  Exponential          4      scenario  0.050            31             16
# 3  Exponential          4      scenario  0.100            31             16
# 4  Exponential          4      scenario  0.500            31             16
#
#    depth_before  nodes_after  leaves_after  depth_after  ...  \
# 0             4           27            14            4  ...
# 1             4           27            14            4  ...
# 2             4           27            14            4  ...
# 3             4           27            14            4  ...
# 4             4           27            14            4  ...
#
#    NRMSE_Train_Affine_after  NRMSE_Test_Affine_after  Min_Epsilon_Before  \
# 0                  0.055661                 0.057129            0.022036
# 1                  0.055661                 0.057129            0.022036
# 2                  0.055661                 0.057129            0.022036
# 3                  0.055661                 0.057129            0.022036
# 4                  0.055661                 0.057129            0.022036
#
#    Max_Epsilon_Before  Min_Epsilon_After  Max_Epsilon_After  Min_h_Before  \
# 0            0.565944           0.011156           0.565944      0.000013
# 1            0.565944           0.011156           0.565944      0.000013
# 2            0.565944           0.011156           0.565944      0.000013
# 3            0.565944           0.011156           0.565944      0.000013
# 4            0.565944           0.011156           0.565944      0.000013
#
#    Max_h_Before  Min_h_After  Max_h_After
# 0      0.437582     0.000013     0.437582
# 1      0.437582     0.000013     0.437582
# 2      0.437582     0.000013     0.437582
# 3      0.437582     0.000013     0.437582
# 4      0.437582     0.000013     0.437582
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   system_name                90 non-null     object
#  1   max_depth                  90 non-null     int64
#  2   cost_function              90 non-null     object
#  3   alpha                      90 non-null     float64
#  4   nodes_before               90 non-null     int64
#  5   leaves_before              90 non-null     int64
#  6   depth_before               90 non-null     int64
#  7   nodes_after                90 non-null     int64
#  8   leaves_after               90 non-null     int64
#  9   depth_after                90 non-null     int64
#  10  NRMSE_Train_Tree           90 non-null     float64
#  11  NRMSE_Test_Tree            90 non-null     float64
#  12  NRMSE_Train_Affine_before  90 non-null     float64
#  13  NRMSE_Test_Affine_before   90 non-null     float64
#  14  NRMSE_Train_Affine_after   90 non-null     float64
#  15  NRMSE_Test_Affine_after    90 non-null     float64
#  16  Min_Epsilon_Before         90 non-null     float64
#  17  Max_Epsilon_Before         90 non-null     float64
#  18  Min_Epsilon_After          90 non-null     float64
#  19  Max_Epsilon_After          90 non-null     float64
#  20  Min_h_Before               90 non-null     float64
#  21  Max_h_Before               90 non-null     float64
#  22  Min_h_After                90 non-null     float64
#  23  Max_h_After                90 non-null     float64
# dtypes: float64(15), int64(7), object(2)
# memory usage: 17.0+ KB

# %%
systems = df["system_name"].unique()
print(systems)
# Out:
# ['Jet' 'Exponential' 'NL1' 'NL2' 'Tank' 'Steam']

# %%
df.head()
# Out:
#   system_name  max_depth cost_function  alpha  nodes_before  leaves_before  \
# 0         Jet          4      scenario  0.001            31             16
# 1         Jet          4      scenario  0.010            31             16
# 2         Jet          4      scenario  0.050            31             16
# 3         Jet          4      scenario  0.100            31             16
# 4         Jet          4      scenario  0.500            31             16
#
#    depth_before  nodes_after  leaves_after  depth_after  ...  \
# 0             4           31            16            4  ...
# 1             4           31            16            4  ...
# 2             4           23            12            4  ...
# 3             4           23            12            4  ...
# 4             4           15             8            4  ...
#
#    NRMSE_Train_Affine_after  NRMSE_Test_Affine_after  Min_Epsilon_Before  \
# 0                  0.000863                 0.000867            0.049331
# 1                  0.000863                 0.000867            0.049331
# 2                  0.001847                 0.001862            0.049331
# 3                  0.001847                 0.001862            0.049331
# 4                  0.002784                 0.002875            0.049331
#
#    Max_Epsilon_Before  Min_Epsilon_After  Max_Epsilon_After  Min_h_Before  \
# 0            0.095232           0.049331           0.095232  6.398304e-07
# 1            0.095232           0.049331           0.095232  6.398304e-07
# 2            0.095232           0.019742           0.067319  6.398304e-07
# 3            0.095232           0.019742           0.067319  6.398304e-07
# 4            0.095232           0.014487           0.056352  6.398304e-07
#
#    Max_h_Before   Min_h_After  Max_h_After
# 0      0.000563  6.398304e-07     0.000563
# 1      0.000563  6.398304e-07     0.000563
# 2      0.000563  6.398304e-07     0.000563
# 3      0.000563  6.398304e-07     0.000563
# 4      0.000563  6.398304e-07     0.000563
#
# [5 rows x 24 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_temp(dataFrame: pd.DataFrame):
    depths = dataFrame["max_depth"].unique()
    # Change ncols to 3
    fig, ax = plt.subplots(nrows=len(depths), ncols=3, figsize=(22, 7 * len(depths)))
    
    if len(depths) == 1:
        ax = np.atleast_2d(ax)
        
    for index, depth in enumerate(depths):
        sub_df = dataFrame[dataFrame["max_depth"] == depth].copy()
        alphas = sub_df["alpha"].astype(str).tolist()
        x = np.arange(len(alphas))
        total_width = 0.8
        
        # --- SUBPLOT 0: Epsilon (Linear) ---
        eps_data = {
            "Min Before": tuple(sub_df["Min_Epsilon_Before"]),
            "Max Before": tuple(sub_df["Max_Epsilon_Before"]),
            "Min After": tuple(sub_df["Min_Epsilon_After"]),
            "Max After": tuple(sub_df["Max_Epsilon_After"])
        }
        w_eps = total_width / len(eps_data)
        for i, (label, vals) in enumerate(eps_data.items()):
            pos = x + (i * w_eps) - (total_width/2) + (w_eps/2)
            rects = ax[index, 0].bar(pos, vals, w_eps, label=label)
            ax[index, 0].bar_label(rects, padding=3, fmt='%.3f', fontsize=7, rotation=90)
        ax[index, 0].set_title(f"Epsilon (Depth {depth})")
        ax[index, 0].legend(loc='upper right', ncol=2, fontsize='small')

        # --- SUBPLOT 1: H Values (Log Scale) ---
        h_data = {
            "Max h Before": tuple(sub_df["Max_h_Before"]),
            # "Min h Before": tuple(sub_df["Min_h_Before"]),
            "Max h After": tuple(sub_df["Max_h_After"]),
            # "Min h After": tuple(sub_df["Min_h_After"])
        }
        w_h = total_width / len(h_data)
        h_colors = ['blue', 'green', 'red', 'black']
        for i, (label, vals) in enumerate(h_data.items()):
            pos = x + (i * w_h) - (total_width/2) + (w_h/2)
            rects = ax[index, 1].bar(pos, vals, w_h, label=label, color=h_colors[i])
            ax[index, 1].bar_label(rects, padding=3, fmt='%.3f', fontsize=7, rotation=90)
        # ax[index, 1].set_yscale('log')
        ax[index, 1].set_title(f"H Values - Log (Depth {depth})")
        ax[index, 1].legend(loc='upper right', ncol=2, fontsize='small')

        # --- SUBPLOT 2: Leaves (New Subplot) ---
        leaves_data = {
            "Leaves Before": tuple(sub_df["leaves_before"]),
            "Leaves After": tuple(sub_df["leaves_after"])
        }
        w_l = total_width / len(leaves_data)
        l_colors = ['purple', 'orange']
        for i, (label, vals) in enumerate(leaves_data.items()):
            pos = x + (i * w_l) - (total_width/2) + (w_l/2)
            rects = ax[index, 2].bar(pos, vals, w_l, label=label, color=l_colors[i])
            # Leaves are usually integers, but using .3f as requested
            ax[index, 2].bar_label(rects, padding=3, fmt='%.3f', fontsize=8, rotation=0)
            
        ax[index, 2].set_title(f"Leaves (Depth {depth})")
        ax[index, 2].legend(loc='upper right')

        # Common Formatting for all 3 subplots in the row
        for col in range(3):
            ax[index, col].set_xticks(x)
            ax[index, col].set_xticklabels(alphas)
            ax[index, col].set_xlabel("Alpha")
            ax[index, col].margins(y=0.25)

    plt.tight_layout()
    plt.show()

# Execution
# systems = df["system_name"].unique()
# for system in systems[3:4]:
#     plot_temp(df[df["system_name"] == system].copy())
plot_temp(df[df["system_name"] == "Jet"].copy())
