# %%
# %load_ext autoreload
# %autoreload 2

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
from CustomTree.customTree import CustomDecisionTree
from CustomTree.decisionTreeToCustomTreeParser import sklearn_tree_to_custom_tree, copy_custom_tree
# from CustomTree.graphicallyShowingTree import visualize_custom_tree #, plot_tree_partitions, plot_tree_partitions_2d_rectangles
from CustomTree.quadratic_constraint_optimization import gurobi_minimax, predict_with_minmax_model
from CustomTree.custom_tree_pruning import global_greedy_prune, global_greedy_prune_with_custom_cost, get_custom_cost_function

# %%
from Visualization.graphicallyShowingTree import visualize_custom_tree
from Visualization.partition_plot_matplotlib import plot_tree_partitions, plot_tree_partitions_2d_rectangles
from Visualization.partition_plot_matplotlib import plot_tree_partitions_3d_scatter, plot_tree_partitions_3d_cubes
from Visualization.partition_plot_plotly import plot_tree_partitions_plotly

# %%
from CustomTree.evaluationMethods import normalized_root_mean_square_error, mean_absolute_error

# %%
# dataset_paths = {
#     "Jet" : r'/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/Benchmarks_Systems/Robust Control for Dynamical Systems With Non-Gaussian Noise via Formal Abstractions/Neural-Abstractions-V2/Dataset/jet/jet_10000/data_jet_10000.csv',
#     "Exponential": r'/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/Benchmarks_Systems/Robust Control for Dynamical Systems With Non-Gaussian Noise via Formal Abstractions/Neural-Abstractions-V2/Dataset/exp/exp_10000/data_exp_10000.csv',
#     "NL1": r'/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/Benchmarks_Systems/Robust Control for Dynamical Systems With Non-Gaussian Noise via Formal Abstractions/Neural-Abstractions-V2/Dataset/nl1/nl1_10000/data_nl1_10000.csv',
#     "NL2": r'/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/Benchmarks_Systems/Robust Control for Dynamical Systems With Non-Gaussian Noise via Formal Abstractions/Neural-Abstractions-V2/Dataset/nl2/nl2_10000/data_nl2_10000.csv',
#     "Tank": r'/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/Benchmarks_Systems/Robust Control for Dynamical Systems With Non-Gaussian Noise via Formal Abstractions/Neural-Abstractions-V2/Dataset/tank/tank_10000/data_tank_10000.csv',
#     "Steam" : r'/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/Benchmarks_Systems/Robust Control for Dynamical Systems With Non-Gaussian Noise via Formal Abstractions/Neural-Abstractions-V2/Dataset/steam/steam_10000/data_steam_10000.csv',
#     # "Navigation" : "/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/RegressionTreeWithRefinment/RegressionTreeRefinment/data_files/RandV_1_RandPosition/navigation_trejectory_dataset.csv",
# }

dataset_paths = {
    "Jet" : r'datasets/data_jet_10000.csv',
    "Exponential": r'datasets/data_exp_10000.csv',
    "NL1": r'datasets/data_nl1_10000.csv',
    "NL2": r'datasets/data_nl2_10000.csv',
    "Tank": r'datasets/data_tank_10000.csv',
    "Steam" : r'datasets/data_steam_10000.csv',
    
    # "Navigation" : "/Users/khalilulrehman/Academic/Phd Italy 2023_26/University of LAquila/Research Papers tasks/RegressionTreeWithRefinment/RegressionTreeRefinment/data_files/RandV_1_RandPosition/navigation_trejectory_dataset.csv",
}

# %% [markdown]
# # Systems Experiment

# %%
# Create a results list to accumulate all experiments
all_results = []

for system_name in dataset_paths:
    print(f"System Name = {system_name}")
    read_df = pd.read_csv(dataset_paths[system_name])
    read_df_dim = read_df.shape[1]
    X_attribute_count = int(read_df_dim/2)
    Y_class_count = int(read_df_dim/2)
    X_read = read_df.iloc[:, :X_attribute_count].values
    y_read = read_df.iloc[:, X_attribute_count:X_attribute_count + Y_class_count].values
    
    X_train, X_test, y_train, y_test = train_test_split(
        X_read, y_read, test_size=0.3, random_state=42
    )
    
    max_depth_for_experiment = [ 4]# , 6, 8, 10, 15]
    for max_depth_item in max_depth_for_experiment:
        print(f"Max Depth = {max_depth_item}")
        dt_model_tree = DecisionTreeRegressor(
            max_depth= max_depth_item, 
            min_samples_leaf=1,
            random_state=42
        )
        
        dt_model_tree.fit(X_train, y_train)

        NRMSE_Train_Tree = normalized_root_mean_square_error(y_true=y_train, y_pred= dt_model_tree.predict(X_train))
        NRMSE_Test_Tree = normalized_root_mean_square_error(y_true=y_test, y_pred= dt_model_tree.predict(X_test))
        print(f"NRMSE Training using Tree = {NRMSE_Train_Tree}")
        print(f"NRMSE Testing using Tree = {NRMSE_Test_Tree}")


        print("Converting Decision Tree to Custom Tree")
        # Converting Decision Tree Regressor To Custom Tree
        custom_tree = sklearn_tree_to_custom_tree(dt_model_tree, X_train)
        print(f"Number of Nodes = {custom_tree.num_nodes()}\nNumber of Leaves = {custom_tree.num_leaves()}\nDepth of Tree = {custom_tree.compute_max_depth()}")
        print("Optimizing Original Leaves")
        for leaf in custom_tree.get_leaves():
            M_val, m0_val, h_val = gurobi_minimax(
                X_train[leaf.sample_indices],
                y_train[leaf.sample_indices],
            )
        
            leaf.h = h_val
            leaf.M = M_val
            leaf.M_0 = m0_val
        print("Evaluating The Affine Model Tree Before Pruning")
        NRMSE_Train_Affine_before = normalized_root_mean_square_error(y_true=y_train, y_pred= predict_with_minmax_model(custom_tree=custom_tree, X=X_train))
        NRMSE_Test_Affine_before = normalized_root_mean_square_error(y_true=y_test, y_pred= predict_with_minmax_model(custom_tree=custom_tree, X=X_test))
        print(f"NRMSE Training using Affine Before Pruning = {NRMSE_Train_Affine_before}")
        print(f"NRMSE Testing using Affine Before Pruning = {NRMSE_Test_Affine_before}")
        cost_functions = ["basic", "average"]
        alphas = [0.001, 0.01, 0.05, 0.1, 0.5]
        for cost_function_item in cost_functions:
            print(f"Cost Function = {cost_function_item}")
            for alpha in alphas:
                print(f"Selected alpha value = {alpha}")
                tree_copy = copy_custom_tree(custom_tree)
                cost_fn = get_custom_cost_function(alpha, cost_type=cost_function_item)
                print("BEFORE")
                nodes_before = tree_copy.num_nodes()
                print("nodes :", nodes_before)
                leaves_before = tree_copy.num_leaves()
                print("leaves:", leaves_before)
                depth_before = tree_copy.compute_max_depth()
                print("depth :", depth_before)
                global_greedy_prune_with_custom_cost(tree_copy, X_train, y_train, cost_fn, plot_tree_each_iteration=False, alpha = alpha, verbose=False)
                
                print("\nAFTER")
                nodes_after = tree_copy.num_nodes()
                print("nodes :", nodes_after)
                leaves_after = tree_copy.num_leaves()
                print("leaves:", leaves_after)
                depth_after = tree_copy.compute_max_depth()
                print("depth :", depth_after)
                NRMSE_Train_Affine_after = normalized_root_mean_square_error(y_true=y_train, y_pred= predict_with_minmax_model(custom_tree=tree_copy, X=X_train))
                NRMSE_Test_Affine_after = normalized_root_mean_square_error(y_true=y_test, y_pred= predict_with_minmax_model(custom_tree=tree_copy, X=X_test))
                print(f"NRMSE Training using Tree = {NRMSE_Train_Affine_after}")
                print(f"NRMSE Testing using Tree = {NRMSE_Test_Affine_after}")

                visualize_custom_tree(tree=tree_copy, save_path=f"graphs/trees/{system_name}/{max_depth_item}/{cost_function_item}/{system_name}-{alpha}.png")
                plot_tree_partitions_plotly(tree_copy, X_train, save_path=f"graphs/partitions/{system_name}/{max_depth_item}/{cost_function_item}/{system_name}-{alpha}.png")
                # Save results
                all_results.append({
                    "system_name": system_name,
                    "max_depth": max_depth_item,
                    "cost_function": cost_function_item,
                    "alpha": alpha,
                    "nodes_before": nodes_before,
                    "leaves_before": leaves_before,
                    "depth_before": depth_before,
                    "nodes_after": nodes_after,
                    "leaves_after": leaves_after,
                    "depth_after": depth_after,
                    "NRMSE_Train_Tree": NRMSE_Train_Tree,
                    "NRMSE_Test_Tree": NRMSE_Test_Tree,
                    "NRMSE_Train_Affine_before": NRMSE_Train_Affine_before,
                    "NRMSE_Test_Affine_before": NRMSE_Test_Affine_before,
                    "NRMSE_Train_Affine_after": NRMSE_Train_Affine_after,
                    "NRMSE_Test_Affine_after": NRMSE_Test_Affine_after
                })

# Save all results to CSV and JSON for future analysis
results_df = pd.DataFrame(all_results)
results_csv_path = "custom_tree_experiments_results.csv"
results_json_path = "custom_tree_experiments_results.json"

results_df.to_csv(results_csv_path, index=False)
results_df.to_json(results_json_path, orient="records", lines=True)

print(f"Results saved to {results_csv_path} and {results_json_path}")
# Out:
# System Name = Jet
# Max Depth = 4
# NRMSE Training using Tree = 0.04207267276611268
# NRMSE Testing using Tree = 0.04393226181415314
# Converting Decision Tree to Custom Tree
# Number of Nodes = 31
# Number of Leaves = 16
# Depth of Tree = 4
# Optimizing Original Leaves
# Evaluating The Affine Model Tree Before Pruning
# NRMSE Training using Affine Before Pruning = 0.0008629039356104543
# NRMSE Testing using Affine Before Pruning = 0.000867102752832912
# Cost Function = basic
# Selected alpha value = 0.001
# BEFORE
# nodes : 31
# leaves: 16
# depth : 4
#
# AFTER
# nodes : 25
# leaves: 13
# depth : 4
# NRMSE Training using Tree = 0.0009372242081022864
# NRMSE Testing using Tree = 0.0009455601850164737
# Selected alpha value = 0.01
# BEFORE
# nodes : 31
# leaves: 16
# depth : 4
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# /home/devunivaq/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning:
#
# Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
#
# AFTER
# nodes : 7
# leaves: 4
# depth : 2
# NRMSE Training using Tree = 0.003348016724669451
# NRMSE Testing using Tree = 0.003374372030122763
# Selected alpha value = 0.05
# BEFORE
# nodes : 31
# leaves: 16
# depth : 4
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# /home/devunivaq/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning:
#
# Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
#
# AFTER
# nodes : 5
# leaves: 3
# depth : 2
# NRMSE Training using Tree = 0.005976980590843747
# NRMSE Testing using Tree = 0.0060143870878833225
# Selected alpha value = 0.1
# BEFORE
# nodes : 31
# leaves: 16
# depth : 4
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# /home/devunivaq/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning:
#
# Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
#
# AFTER
# nodes : 3
# leaves: 2
# depth : 1
# NRMSE Training using Tree = 0.013037225971897118
# NRMSE Testing using Tree = 0.0131873954044561
# Selected alpha value = 0.5
# BEFORE
# nodes : 31
# leaves: 16
# depth : 4
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# /home/devunivaq/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning:
#
# Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Failure:interrupted
# ---------------------------------------------------------------------------
# GurobiError                               Traceback (most recent call last)
# File ~/ResearchTasks/Custom-Tree-Pruning/CustomTree/quadratic_constraint_optimization.py:79, in gurobi_minimax(X_leaf, y_leaf, verbose)
#      78 model.setObjective(h, GRB.MINIMIZE)
# ---> 79 model.optimize()
#      81 if model.Status in (GRB.OPTIMAL, GRB.SUBOPTIMAL) or model.SolCount > 0:
#
# File src/gurobipy/_model.pyx:926, in gurobipy._model.Model.optimize()
#
# GurobiError: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
#
# During handling of the above exception, another exception occurred:
#
# SolverError                               Traceback (most recent call last)
# Cell In[10], line 68
#      66 depth_before = tree_copy.compute_max_depth()
#      67 print("depth :", depth_before)
# ---> 68 global_greedy_prune_with_custom_cost(tree_copy, X_train, y_train, cost_fn, plot_tree_each_iteration=False, alpha = alpha, verbose=False)
#      70 print("\nAFTER")
#      71 nodes_after = tree_copy.num_nodes()
#
# File ~/ResearchTasks/Custom-Tree-Pruning/CustomTree/custom_tree_pruning.py:211, in global_greedy_prune_with_custom_cost(tree, X, y, cost_fn, plot_tree_each_iteration, alpha, verbose)
#     208     print(f"[ITER {iteration}] Pruning node {best_node.node_id} with delta={best_delta:.4f}")
#     210 # Apply best prune
# --> 211 collapse_node(tree, best_node, X, y)
#     213 if plot_tree_each_iteration:
#     214     visualize_custom_tree(tree)
#
# File ~/ResearchTasks/Custom-Tree-Pruning/CustomTree/custom_tree_pruning.py:46, in collapse_node(tree, node, X, y)
#      43 node.threshold = None
#      45 # recompute leaf model
# ---> 46 M_val, m0_val, h_val = gurobi_minimax(
#      47     X[node.sample_indices],
#      48     y[node.sample_indices]
#      49 )
#      51 node.M = M_val
#      52 node.M_0 = m0_val
#
# File ~/ResearchTasks/Custom-Tree-Pruning/CustomTree/quadratic_constraint_optimization.py:95, in gurobi_minimax(X_leaf, y_leaf, verbose)
#      93     print("Gurobi encountered an error:", str(e))
#      94     print("Gurobi encountered an error. Falling back to CVXPY solver.")
# ---> 95     return cvxpy_minimax(X_leaf, y_leaf)
#      96 raise
#
# File ~/ResearchTasks/Custom-Tree-Pruning/CustomTree/quadratic_constraint_optimization.py:35, in cvxpy_minimax(X_leaf, y_leaf)
#      33 # Objective: minimize worst-case squared error h
#      34 problem = cp.Problem(cp.Minimize(h), constraints)
# ---> 35 problem.solve(solver=cp.SCS)  # or ECOS, OSQP, GUROBI if licensed
#      37 return M.value, m0.value, h.value
#
# File ~/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:609, in Problem.solve(self, *args, **kwargs)
#     606         raise ValueError(
#     607             "Cannot specify both 'solver' and 'solver_path'. Please choose one.")
#     608     return self._solve_solver_path(solve_func,solver_path, args, kwargs)
# --> 609 return solve_func(self, *args, **kwargs)
#
# File ~/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1222, in Problem._solve(self, solver, warm_start, verbose, bibtex, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1220 end = time.time()
#    1221 self._solve_time = end - start
# -> 1222 self.unpack_results(solution, solving_chain, inverse_data)
#    1223 if verbose:
#    1224     print(_FOOTER)
#
# File ~/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1547, in Problem.unpack_results(self, solution, chain, inverse_data)
#    1545     warnings.warn(INF_OR_UNB_MESSAGE)
#    1546 if solution.status in s.ERROR:
# -> 1547     raise error.SolverError(
#    1548             "Solver '%s' failed. " % chain.solver.name() +
#    1549             "Try another solver, or solve with verbose=True for more "
#    1550             "information.")
#    1552 self.unpack(solution)
#    1553 self._solver_stats = SolverStats.from_dict(self._solution.attr,
#    1554                                  chain.solver.name())
#
# SolverError: Solver 'SCS' failed. Try another solver, or solve with verbose=True for more information.

# %% [markdown]
# # Parallel Processing Code

# %%
import os
from concurrent.futures import ProcessPoolExecutor, as_completed

# %%
from pathlib import Path

def ensure_dir(path):
    Path(path).mkdir(parents=True, exist_ok=True)

# %%
def run_single_system(system_name, csv_path):

    print(f"==== Running system: {system_name} ====")

    results = []

    read_df = pd.read_csv(csv_path)
    read_df_dim = read_df.shape[1]

    X_attribute_count = int(read_df_dim / 2)
    Y_class_count = int(read_df_dim / 2)

    X_read = read_df.iloc[:, :X_attribute_count].values
    y_read = read_df.iloc[:, X_attribute_count:X_attribute_count + Y_class_count].values

    X_train, X_test, y_train, y_test = train_test_split(
        X_read, y_read, test_size=0.3, random_state=42
    )

    max_depth_for_experiment = [4, 6, 8, 10, 15]
    cost_functions = ["basic", "average"]
    alphas = [0.001, 0.01, 0.05, 0.1, 0.5]

    for max_depth_item in max_depth_for_experiment:

        dt_model_tree = DecisionTreeRegressor(
            max_depth=max_depth_item,
            min_samples_leaf=1,
            random_state=42,
        )

        dt_model_tree.fit(X_train, y_train)

        NRMSE_Train_Tree = normalized_root_mean_square_error(
            y_train, dt_model_tree.predict(X_train)
        )

        NRMSE_Test_Tree = normalized_root_mean_square_error(
            y_test, dt_model_tree.predict(X_test)
        )

        custom_tree = sklearn_tree_to_custom_tree(dt_model_tree, X_train)

        for leaf in custom_tree.get_leaves():
            M_val, m0_val, h_val = gurobi_minimax(
                X_train[leaf.sample_indices],
                y_train[leaf.sample_indices],
            )
            leaf.h = h_val
            leaf.M = M_val
            leaf.M_0 = m0_val

        # BEFORE pruning metrics
        NRMSE_Train_Affine_before = normalized_root_mean_square_error(
            y_train,
            predict_with_minmax_model(custom_tree, X_train),
        )

        NRMSE_Test_Affine_before = normalized_root_mean_square_error(
            y_test,
            predict_with_minmax_model(custom_tree, X_test),
        )

        for cost_function_item in cost_functions:
            for alpha in alphas:

                tree_copy = copy_custom_tree(custom_tree)
                cost_fn = get_custom_cost_function(alpha, cost_type=cost_function_item)

                nodes_before = tree_copy.num_nodes()
                leaves_before = tree_copy.num_leaves()
                depth_before = tree_copy.compute_max_depth()

                global_greedy_prune_with_custom_cost(
                    tree_copy,
                    X_train,
                    y_train,
                    cost_fn,
                    plot_tree_each_iteration=False,
                    alpha=alpha,
                    verbose=False,
                )

                nodes_after = tree_copy.num_nodes()
                leaves_after = tree_copy.num_leaves()
                depth_after = tree_copy.compute_max_depth()

                NRMSE_Train_Affine_after = normalized_root_mean_square_error(
                    y_train,
                    predict_with_minmax_model(tree_copy, X_train),
                )

                NRMSE_Test_Affine_after = normalized_root_mean_square_error(
                    y_test,
                    predict_with_minmax_model(tree_copy, X_test),
                )

                # -----------------------------
                # SAVE GRAPHS
                # -----------------------------

                tree_dir = f"graphs/trees/{system_name}/{max_depth_item}/{cost_function_item}"
                part_dir = f"graphs/partitions/{system_name}/{max_depth_item}/{cost_function_item}"

                ensure_dir(tree_dir)
                ensure_dir(part_dir)

                visualize_custom_tree(
                    tree=tree_copy,
                    save_path=f"{tree_dir}/{system_name}-{alpha}.png",
                )

                plot_tree_partitions_plotly(
                    tree_copy,
                    X_train,
                    save_path=f"{part_dir}/{system_name}-{alpha}.png",
                )

                # -----------------------------
                # RECORD RESULTS
                # -----------------------------

                results.append({
                    "system": system_name,
                    "max_depth": max_depth_item,
                    "cost_function": cost_function_item,
                    "alpha": alpha,

                    "nodes_before": nodes_before,
                    "leaves_before": leaves_before,
                    "depth_before": depth_before,

                    "nodes_after": nodes_after,
                    "leaves_after": leaves_after,
                    "depth_after": depth_after,

                    "NRMSE_tree_train": NRMSE_Train_Tree,
                    "NRMSE_tree_test": NRMSE_Test_Tree,

                    "NRMSE_affine_train_before": NRMSE_Train_Affine_before,
                    "NRMSE_affine_test_before": NRMSE_Test_Affine_before,

                    "NRMSE_affine_train_after": NRMSE_Train_Affine_after,
                    "NRMSE_affine_test_after": NRMSE_Test_Affine_after,
                })

    return results

# %%
all_results = []

with ProcessPoolExecutor(max_workers=os.cpu_count()) as executor:

    futures = {
        executor.submit(run_single_system, name, dataset_paths[name]): name
        for name in dataset_paths
    }

    for future in as_completed(futures):
        system_name = futures[future]

        try:
            system_results = future.result()
            all_results.extend(system_results)
            print(f"✔ Finished {system_name}")

        except Exception as e:
            print(f"❌ Failed {system_name}: {e}")

results_df = pd.DataFrame(all_results)

results_df.to_csv("parallel_tree_pruning_results.csv", index=False)
results_df.to_pickle("parallel_tree_pruning_results.pkl")

print("Saved results!")
# Out:
# ==== Running system: Jet ======== Running system: NL1 ======== Running system: Exponential ======== Running system: Steam ======== Running system: Tank ====
# ==== Running system: NL2 ====
#
#
#
#
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# ❌ Failed Jet: Invalid format 'html'.
#     Supported formats: ('png', 'jpg', 'jpeg', 'webp', 'svg', 'json', 'pdf')
# ❌ Failed NL1: Invalid format 'html'.
#     Supported formats: ('png', 'jpg', 'jpeg', 'webp', 'svg', 'json', 'pdf')
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# /home/devunivaq/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning:
#
# Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# /home/devunivaq/ResearchTasks/Custom-Tree-Pruning/venv/lib/python3.10/site-packages/cvxpy/problems/problem.py:1539: UserWarning:
#
# Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Only 2D or 3D features are supported for plotting.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# ❌ Failed Exponential: Invalid format 'html'.
#     Supported formats: ('png', 'jpg', 'jpeg', 'webp', 'svg', 'json', 'pdf')
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# ❌ Failed NL2: Invalid format 'html'.
#     Supported formats: ('png', 'jpg', 'jpeg', 'webp', 'svg', 'json', 'pdf')
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Only 2D or 3D features are supported for plotting.
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# Gurobi encountered an error: Model too large for size-limited license; visit https://gurobi.com/unrestricted for more information
# Gurobi encountered an error. Falling back to CVXPY solver.
# Using CVXPY minimax solver...
# ❌ Failed Steam: The node 0 is not in the digraph.
# Process ForkProcess-68:
# Process ForkProcess-74:
# Process ForkProcess-65:
# Process ForkProcess-85:
# Process ForkProcess-84:
# Process ForkProcess-82:
# Process ForkProcess-67:
# Process ForkProcess-55:
# Process ForkProcess-81:
# Process ForkProcess-63:
# Process ForkProcess-70:
# Process ForkProcess-71:
# Process ForkProcess-72:
# Process ForkProcess-62:
# Process ForkProcess-52:
# Process ForkProcess-88:
# Process ForkProcess-87:
# Process ForkProcess-78:
# Process ForkProcess-56:
# Process ForkProcess-73:
# Process ForkProcess-69:
# Process ForkProcess-79:
# Process ForkProcess-66:
# Process ForkProcess-58:
# Process ForkProcess-77:
# Process ForkProcess-59:
# Process ForkProcess-86:
# Process ForkProcess-80:
# Process ForkProcess-54:
# Process ForkProcess-76:
# Process ForkProcess-64:
# Process ForkProcess-57:
# Process ForkProcess-75:
# Process ForkProcess-51:
# Failure:interrupted
# Process ForkProcess-53:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkProcess-83:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkProcess-61:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkProcess-60:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/concurrent/futures/process.py", line 240, in _process_worker
#     call_item = call_queue.get(block=True)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 103, in get
#     res = self._recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 102, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 10
#       5 futures = {
#       6     executor.submit(run_single_system, name, dataset_paths[name]): name
#       7     for name in dataset_paths
#       8 }
# ---> 10 for future in as_completed(futures):
#      11     system_name = futures[future]
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#
# File /usr/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     319 if timeout is None:
# --> 320     waiter.acquire()
#     321     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 3
#       1 all_results = []
# ----> 3 with ProcessPoolExecutor(max_workers=os.cpu_count()) as executor:
#       5     futures = {
#       6         executor.submit(run_single_system, name, dataset_paths[name]): name
#       7         for name in dataset_paths
#       8     }
#      10     for future in as_completed(futures):
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:649, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     648 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649     self.shutdown(wait=True)
#     650     return False
#
# File /usr/lib/python3.10/concurrent/futures/process.py:780, in ProcessPoolExecutor.shutdown(self, wait, cancel_futures)
#     777         self._executor_manager_thread_wakeup.wakeup()
#     779 if self._executor_manager_thread is not None and wait:
# --> 780     self._executor_manager_thread.join()
#     781 # To reduce the risk of opening too many files, remove references to
#     782 # objects that use file descriptors.
#     783 self._executor_manager_thread = None
#
# File /usr/lib/python3.10/threading.py:1096, in Thread.join(self, timeout)
#    1093     raise RuntimeError("cannot join current thread")
#    1095 if timeout is None:
# -> 1096     self._wait_for_tstate_lock()
#    1097 else:
#    1098     # the behavior of a negative timeout isn't documented, but
#    1099     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1100     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /usr/lib/python3.10/threading.py:1116, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1113     return
#    1115 try:
# -> 1116     if lock.acquire(block, timeout):
#    1117         lock.release()
#    1118         self._stop()
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
# plot_tree_partitions(custom_tree, X_train, ax=ax)
plot_tree_partitions_2d_rectangles(custom_tree, X_train, ax)
plt.show()
# plot_tree_partitions_plotly(custom_tree, X_train)

# %%
plot_tree_partitions_3d_cubes(custom_tree, X_train)
